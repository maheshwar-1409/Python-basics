# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshwar-1409/Python-basics/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# strings : immutable in python , can't be chnaged/modified

# %%
c='hello'
print(c[1])
print(c[-1]) #neg indexing
print(c[0:3])#slicing
print(c[1:])
print(c[-2:])
print(c[2:5:2]) #step
print(c[::-1]) #reverse
# Out:
# e
# o
# hel
# ello
# lo
# lo
# olleh

# %%
s="hi"
del s
#print(s);
del(s[0]) #not posible/immutable no change
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5888/311060123.py in <cell line: 0>()
#       2 del s
#       3 #print(s);
# ----> 4 del(s[0]) #not posible
#
# NameError: name 's' is not defined

# %%
print("hello"+"world")
print("*"*6)
# Out:
# '******'

# %%
print("mumbai">"pune") #disctionary
print("KOL">"kol")
# Out:
# False
# False

# %%
'hello' and "world" #""->false
# Out:
# 'world'

# %%
c='hello'
for i in c:
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
# Function	Description	Example
# length() / len()	Returns the number of characters	      len("Hello") → 5
# upper()	Converts text to uppercase	                  "hello".upper() → "HELLO"
# lower()	Converts text to lowercase	                "HELLO".lower() → "hello"
# strip()	Removes leading and trailing spaces         	" hi ".strip() → "hi"
# replace()	Replaces part of a string           	      "cat".replace("c","b") → "bat"
# find()	Finds the position of a substring	             "Hello".find("e") → 1
# substring() / slicing	Extracts part of a string          	"Hello"[1:4] → "ell"
# split()	Splits a string into a list	                 "a,b,c".split(",") → ['a','b','c']
# join()	Joins elements into a string	                    "-".join(['a','b']) → "a-b"
# startswith()	Checks if a string starts with a given text   	"Hello".startswith("He") → True
# endswith()	Checks if a string ends with a given text	        "Hello".endswith("lo") → True
#isalnum(), isalpha(), isdigit(), isdecimal()
"hello".count("ll")
"hi".find("i") #if not found -1 but .index() gives erroe
"hello {}".format("world")
# Out:
# 'hello world'
